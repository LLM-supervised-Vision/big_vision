# %%
import tensorflow_datasets as tfds

# %%
ds = tfds.load("laion2b", data_dir="/scratch/zy2091/tensorflow_datasets", download=False)
# Out:
# 2024-07-06 04:32:22.660181: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-07-06 04:32:22.664148: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-07-06 04:32:23.536307: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-07-06 04:32:23.713602: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:479] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# ...

# %%
len(ds["train"])
# Out:
# 20000000

# %%
ds_train = ds["train"]

# %%
from PIL import Image
iterator = iter(ds_train)
for i in range(10):
    batch = next(iterator)
    image = Image.fromarray(batch['image'].numpy())
    image.show()
    print(batch['caption'])
    print(batch['url'])
# Out:
# <PIL.Image.Image image mode=RGB size=384x480>
# tf.Tensor(b'Chanel - Metallic Necklace - Lyst', shape=(), dtype=string)
# tf.Tensor(b'https://cdnb.lystit.com/520/650/n/photos/vestiairecollective/757858a6/chanel-Silver-Pre-owned-Necklace.jpeg', shape=(), dtype=string)
# <PIL.Image.Image image mode=RGB size=450x299>
# tf.Tensor(b'lybia: On the streets of Hurghada, Egypt', shape=(), dtype=string)
# tf.Tensor(b'https://us.123rf.com/450wm/evdoha/evdoha1308/evdoha130801325/21293957-on-the-streets-of-hurghada-egypt.jpg?ver=6', shape=(), dtype=string)
# <PIL.Image.Image image mode=RGB size=256x256>
# tf.Tensor(b'likeable-blog-1337-2x', shape=(), dtype=string)
# tf.Tensor(b'https://perfectlyimperfect32wordpresscom.files.wordpress.com/2017/03/likeable-blog-1337-2x.png?w=663', shape=(), dtype=string)
# <PIL.Image.Image image mode=RGB size=384x554>
# tf.Tensor(b'FIERCELY SEXY BASQUE - Korsetti - white/nude', shape=(), dtype=string)
# ...

# %%
iterator = iter(ds_train)
next(iterator).keys()
# Out:
# dict_keys(['caption', 'image', 'license', 'nsfw', 'original_height', 'original_width', 'similarity', 'url'])
